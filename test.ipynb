# %%
f = open('search_urls.txt', 'w+')
url = 'https://www.amazon.com/s?k=Processor&ref=nb_sb_noss_2'
f.write(url)
f.write('\n')


for i in range(2,51):
    url = 'https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=' + str(i) + '&qid=1594555641&ref=sr_pg_' + str(i)
    f.write(url)
    f.write('\n')

f.close()

# %%
# search.py
import selectorlib
from selectorlib import Extractor
import requests
import json
from time import sleep
from fake_useragent import UserAgent


# Create an Extractor by reading from the YAML file
e = Extractor.from_yaml_file('search.yml')


def scrape(url):
    ua = UserAgent()

    headers = {
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': ua.random,
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-user': '?1',
        'sec-fetch-dest': 'document',
        'referer': 'https://www.amazon.com/',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
    }

    # Download the page using requests
    print("Downloading %s" % url)
    r = requests.get(url, headers=headers)
    # Simple check to check if page was blocked (Usually 503)
    if r.status_code > 500:
        if "To discuss automated access to Amazon data please contact" in r.text:
            print(
                "Page %s was blocked by Amazon. Please try using better proxies\n" % url)
        else:
            print("Page %s must have been blocked by Amazon as the status code was %d" % (
                url, r.status_code))
        return None
    # Pass the HTML of the page and create
    return e.extract(r.text)


# product_data = []
with open("search_urls.txt", 'r') as urllist, open('search_output.jsonl', 'w') as outfile:
    f = open('product_urls.txt','w')
    for url in urllist.read().splitlines():
        data = scrape(url)

       
        if data:
            try:
                for product in data['products']:
                    product['url'] = 'https://www.amazon.com' + product['url']
                    f.write(product['url'])
                    f.write('\n')

                    json.dump(product, outfile)
                    outfile.write(", \n")
                    # sleep(5)
                
            except:
                continue
    f.close()
# Out:
# Error occurred during loading data. Trying to use cache server https://fake-useragent.herokuapp.com/browsers/0.1.11
# Traceback (most recent call last):
#   File "C:\Users\ShekharBiswas\Anaconda3\lib\site-packages\fake_useragent\utils.py", line 154, in load
#     for item in get_browsers(verify_ssl=verify_ssl):
#   File "C:\Users\ShekharBiswas\Anaconda3\lib\site-packages\fake_useragent\utils.py", line 99, in get_browsers
#     html = html.split('<table class="w3-table-all notranslate">')[1]
# IndexError: list index out of range
# Downloading https://www.amazon.com/s?k=Processor&ref=nb_sb_noss_2
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=2&qid=1594555641&ref=sr_pg_2
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=3&qid=1594555641&ref=sr_pg_3
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=4&qid=1594555641&ref=sr_pg_4
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=5&qid=1594555641&ref=sr_pg_5
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=6&qid=1594555641&ref=sr_pg_6
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=7&qid=1594555641&ref=sr_pg_7
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=8&qid=1594555641&ref=sr_pg_8
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=9&qid=1594555641&ref=sr_pg_9
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=10&qid=1594555641&ref=sr_pg_10
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=11&qid=1594555641&ref=sr_pg_11
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=12&qid=1594555641&ref=sr_pg_12
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=13&qid=1594555641&ref=sr_pg_13
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=14&qid=1594555641&ref=sr_pg_14
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=15&qid=1594555641&ref=sr_pg_15
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=16&qid=1594555641&ref=sr_pg_16
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=17&qid=1594555641&ref=sr_pg_17
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=18&qid=1594555641&ref=sr_pg_18
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=19&qid=1594555641&ref=sr_pg_19
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=20&qid=1594555641&ref=sr_pg_20
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=21&qid=1594555641&ref=sr_pg_21
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=22&qid=1594555641&ref=sr_pg_22
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=23&qid=1594555641&ref=sr_pg_23
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=24&qid=1594555641&ref=sr_pg_24
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=25&qid=1594555641&ref=sr_pg_25
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=26&qid=1594555641&ref=sr_pg_26
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=27&qid=1594555641&ref=sr_pg_27
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=28&qid=1594555641&ref=sr_pg_28
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=29&qid=1594555641&ref=sr_pg_29
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=30&qid=1594555641&ref=sr_pg_30
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=31&qid=1594555641&ref=sr_pg_31
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=32&qid=1594555641&ref=sr_pg_32
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=33&qid=1594555641&ref=sr_pg_33
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=34&qid=1594555641&ref=sr_pg_34
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=35&qid=1594555641&ref=sr_pg_35
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=36&qid=1594555641&ref=sr_pg_36
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=37&qid=1594555641&ref=sr_pg_37
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=38&qid=1594555641&ref=sr_pg_38
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=39&qid=1594555641&ref=sr_pg_39
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=40&qid=1594555641&ref=sr_pg_40
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=41&qid=1594555641&ref=sr_pg_41
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=42&qid=1594555641&ref=sr_pg_42
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=43&qid=1594555641&ref=sr_pg_43
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=44&qid=1594555641&ref=sr_pg_44
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=45&qid=1594555641&ref=sr_pg_45
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=46&qid=1594555641&ref=sr_pg_46
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=47&qid=1594555641&ref=sr_pg_47
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=48&qid=1594555641&ref=sr_pg_48
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=49&qid=1594555641&ref=sr_pg_49
# Downloading https://www.amazon.com/s?k=Processor&i=computers-intl-ship&page=50&qid=1594555641&ref=sr_pg_50
